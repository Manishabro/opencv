# %%
import cv2

# %%
from deepface import DeepFace
# Out:
# 24-07-25 19:32:14 - Directory C:\Users\reval/.deepface created
# 24-07-25 19:32:14 - Directory C:\Users\reval/.deepface/weights created

# %%
img=cv2.imread('Angry.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
imgg=(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
plt.imshow(imgg);

# %%
pred=DeepFace.analyze(imgg)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.52it/s]

# %%
pred
# Out:
# [{'emotion': {'angry': 0.5186033435165882,
#    'disgust': 1.5167336787566543e-10,
#    'fear': 99.47574138641357,
#    'happy': 0.002677475640666671,
#    'sad': 6.29153646514169e-05,
#    'surprise': 0.002914465767389629,
#    'neutral': 1.2332086306993117e-10},
#   'dominant_emotion': 'fear',
#   'region': {'x': 183,
#    'y': 68,
#    'w': 152,
#    'h': 152,
#    'left_eye': (287, 128),
#    'right_eye': (234, 127)},
#   'face_confidence': 0.89,
#   'age': 25,
#   'gender': {'Woman': 1.842255272777038e-05, 'Man': 99.99997615814209},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.0029840181014151312,
#    'indian': 0.28326469473540783,
#    'black': 0.002237796979898121,
#    'white': 89.91872072219849,
#    'middle eastern': 5.637535080313683,
#    'latino hispanic': 4.155265167355537},
#   'dominant_race': 'white'}]

# %%
type(pred)
# Out:
# list

# %%
data = {'emotion': {'angry': 52.97316312789917,
                     'disgust': 1.2661327541962919e-08,
                     'fear': 1.2440040707588196,
                     'happy': 0.0006009470325807342,
                     'sad': 34.86915826797485,
                     'surprise': 0.0038716938433935866,
                     'neutral': 10.909201204776764},
         'dominant_emotion': 'angry',
         'region': {'x': 206,
                    'y': 71,
                    'w': 113,
                    'h': 113,
                    'left_eye': None,
                    'right_eye': None},
         'face_confidence': 0.95,
         'age': 26,
         'gender': {'Woman': 0.06287714932113886, 'Man': 99.93712306022644},
         'dominant_gender': 'Man',
         'race': {'asian': 0.27394420467317104,
                  'indian': 0.011339824413880706,
                  'black': 0.0006015252893121215,
                  'white': 95.55931687355042,
                  'middle eastern': 1.5067902393639088,
                  'latino hispanic': 2.648013085126877},
         'dominant_race': 'white'}

# %%
data['dominant_emotion']
# Out:
# 'angry'

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
cv2.CascadeClassifier
# Out:
# cv2.CascadeClassifier

# %%
gray=cv2.cvtColor(imgg,cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)

# %%
for(x,y,w,h) in faces:
    cv2.rectangle(imgg,(x,y),(x+w,y+h),(0,255,0),2)

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(imgg,
           data['dominant_emotion'],
           (0,50),
           font,1,
           (0,255,0),
           2,
           cv2.LINE_4);

# %%
plt.imshow(imgg)

# %%
img=cv2.imread('Happy.jpeg')

# %%
plt.imshow(img);

# %%
imgg=(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
plt.imshow(imgg)

# %%
pred=DeepFace.analyze(imgg)
# Out:
#  51%|██████████████████████████████████████                                     | 273M/537M [1:12:40<1:10:31, 62.5kB/s]
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:12<00:00,  3.07s/it]

# %%
pred
# Out:
# [{'emotion': {'angry': 2.0827456557365797e-07,
#    'disgust': 2.987511521942837e-15,
#    'fear': 1.916101347443253e-06,
#    'happy': 99.81414674604814,
#    'sad': 5.150559841425401e-07,
#    'surprise': 0.0007947891864089835,
#    'neutral': 0.18506208373603725},
#   'dominant_emotion': 'happy',
#   'region': {'x': 92,
#    'y': 35,
#    'w': 67,
#    'h': 67,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.92,
#   'age': 32,
#   'gender': {'Woman': 8.499598038724798e-05, 'Man': 99.99991655349731},
#   'dominant_gender': 'Man',
#   'race': {'asian': 13.24906200170517,
#    'indian': 9.227032959461212,
#    'black': 41.08406603336334,
#    'white': 2.6308907195925713,
#    'middle eastern': 2.3518405854701996,
#    'latino hispanic': 31.45710825920105},
#   'dominant_race': 'black'}]

# %%
data={'emotion': {'angry': 5.878926234714754e-08,
   'disgust': 1.0404160172283738e-10,
   'fear': 5.040183737037296e-06,
   'happy': 98.24777245521545,
   'sad': 0.0003752615612029331,
   'surprise': 0.0004068238467880292,
   'neutral': 1.7514381557703018},
  'dominant_emotion': 'happy',
  'region': {'x': 214,
   'y': 200,
   'w': 424,
   'h': 424,
   'left_eye': (500, 362),
   'right_eye': (343, 377)},
  'face_confidence': 0.92,
  'age': 22,
  'gender': {'Woman': 0.1224566251039505, 'Man': 99.87754225730896},
  'dominant_gender': 'Man',
  'race': {'asian': 43.87812614440918,
   'indian': 10.926619917154312,
   'black': 9.003175795078278,
   'white': 4.426278918981552,
   'middle eastern': 2.431628480553627,
   'latino hispanic': 29.334166646003723},
  'dominant_race': 'asian'}

# %%
data['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
cv2.CascadeClassifier
# Out:
# cv2.CascadeClassifier

# %%
gray=cv2.cvtColor(imgg,cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)

# %%
for(x,y,w,h) in faces:
    cv2.rectangle(imgg,(x,y),(x+w,y+h),(0,255,0),2)

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(imgg,
           data['dominant_emotion'],
           (0,50),
           font,1,
           (0,255,0),
           3,
           cv2.LINE_AA);

# %%
plt.imshow(imgg)
